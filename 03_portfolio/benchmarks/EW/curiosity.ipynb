# %% [markdown]
# **Purpose:** `curiosity.ipynb` — part of `03_portfolio/benchmarks/EW` (see the stage README).
#
# **Notes:** paths resolve via `src.config` (run `pip install -e .` from the repo root first).

# %%
import sys
from pathlib import Path

from src.metrics import PortfolioMetrics
pm = PortfolioMetrics()

import numpy as np

# %%
T, N = 500, 11

assets = ['XLB', 'XLC', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLRE', 'XLU', 'XLV', 'XLY']

for asset in assets:
    weights = np.zeros((T, N))
    weights[:, assets.index(asset)] = 1.0

    print(f"Metrics for {asset}:")
    print(pm.summary(weights))
# Out:
# Metrics for XLB:
# {'cumulative_return': np.float64(0.10241626898061718), 'volatility': np.float64(0.16983937193315382), 'sharpe_ratio': np.float64(0.07346697542373794), 'max_drawdown': np.float64(-0.23165829496535015)}
# Metrics for XLC:
# {'cumulative_return': np.float64(0.7035311469310186), 'volatility': np.float64(0.1799584533131745), 'sharpe_ratio': np.float64(1.2988217857041502), 'max_drawdown': np.float64(-0.17970842891167493)}
# Metrics for XLE:
# {'cumulative_return': np.float64(0.11547030720093576), 'volatility': np.float64(0.21980655703457516), 'sharpe_ratio': np.float64(0.12922472457346845), 'max_drawdown': np.float64(-0.2013729578082304)}
# Metrics for XLF:
# {'cumulative_return': np.float64(0.6041119586048895), 'volatility': np.float64(0.1673248716636156), 'sharpe_ratio': np.float64(1.2026546683542896), 'max_drawdown': np.float64(-0.15540282261100957)}
# Metrics for XLI:
# {'cumulative_return': np.float64(0.41701488523059504), 'volatility': np.float64(0.16499332500911157), 'sharpe_ratio': np.float64(0.8378458663286062), 'max_drawdown': np.float64(-0.18490706190636597)}
# Metrics for XLK:
# {'cumulative_return': np.float64(0.47791175852972745), 'volatility': np.float64(0.24697232446467382), 'sharpe_ratio': np.float64(0.7135127475337938), 'max_drawdown': np.float64(-0.25656301021496786)}
# Metrics for XLP:
# {'cumulative_return': np.float64(0.1524160299072872), 'volatility': np.float64(0.12074742320538628), 'sharpe_ratio': np.float64(0.22977144456541862), 'max_drawdown': np.float64(-0.12393193871538043)}
# Metrics for XLRE:
# {'cumulative_return': np.float64(0.17686223368326015), 'volatility': np.float64(0.18104136518713312), 'sharpe_ratio': np.float64(0.26190786048936315), 'max_drawdown': np.float64(-0.16739421533553736)}
# Metrics for XLU:
# {'cumulative_return': np.float64(0.3286080265956466), 'volatility': np.float64(0.17175648145934633), 'sharpe_ratio': np.float64(0.6227869041215648), 'max_drawdown': np.float64(-0.17257787170989025)}
# Metrics for XLV:
# {'cumulative_return': np.float64(0.049528379786451415), 'volatility': np.float64(0.1349150570001613), 'sharpe_ratio': np.float64(-0.13014085629197886), 'max_drawdown': np.float64(-0.17109001628908072)}
# Metrics for XLY:
# {'cumulative_return': np.float64(0.30141625908336533), 'volatility': np.float64(0.21948664701160975), 'sharpe_ratio': np.float64(0.4817036023131544), 'max_drawdown': np.float64(-0.2600740112187784)}
